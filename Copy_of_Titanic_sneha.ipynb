# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15  \
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
#      Unnamed: 16
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 886          NaN
# 887          NaN
# 888          NaN
# 889          NaN
# 890          NaN
#
# [891 rows x 17 columns]

# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15  Unnamed: 16
# 0    man        True  NaN  Southampton    no  False          NaN          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN          NaN
# 3  woman       False    C  Southampton   yes  False          NaN          NaN
# 4    man        True  NaN  Southampton    no   True          NaN          NaN

# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15  \
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
#      Unnamed: 16
# 888          NaN
# 889          NaN
# 890          NaN

# %%
import pandas as pd
df=pd.read_csv("/content/titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
# dtypes: bool(2), float64(4), int64(4), object(7)
# memory usage: 106.3+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Unnamed: 15  Unnamed: 16
# count          0.0          0.0
# mean           NaN          NaN
# std            NaN          NaN
# min            NaN          NaN
# 25%            NaN          NaN
# 50%            NaN          NaN
# 75%            NaN          NaN
# max            NaN          NaN

# %%
df[:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15  Unnamed: 16
# 0    man        True  NaN  Southampton    no  False          NaN          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN          NaN

# %%
df[2:67]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 62         0       1    male  45.0      1      0  83.4750        S   First
# 63         0       3    male   4.0      3      2  27.9000        S   Third
# 64         0       1    male   NaN      0      0  27.7208        C   First
# 65         1       3    male   NaN      1      1  15.2458        C   Third
# 66         1       2  female  29.0      0      0  10.5000        S  Second
#
#       who  adult_male deck  embark_town alive  alone  Unnamed: 15  Unnamed: 16
# 2   woman       False  NaN  Southampton   yes   True          NaN          NaN
# 3   woman       False    C  Southampton   yes  False          NaN          NaN
# 4     man        True  NaN  Southampton    no   True          NaN          NaN
# 5     man        True  NaN   Queenstown    no   True          NaN          NaN
# 6     man        True    E  Southampton    no   True          NaN          NaN
# ..    ...         ...  ...          ...   ...    ...          ...          ...
# 62    man        True    C  Southampton    no  False          NaN          NaN
# 63  child       False  NaN  Southampton    no  False          NaN          NaN
# 64    man        True  NaN    Cherbourg    no   True          NaN          NaN
# 65    man        True  NaN    Cherbourg   yes  False          NaN          NaN
# 66  woman       False    F  Southampton   yes   True          NaN          NaN
#
# [65 rows x 17 columns]

# %%
df[45:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 45          0       3    male   NaN      0      0   8.0500        S   Third
# 46          0       3    male   NaN      1      0  15.5000        Q   Third
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 48          0       3    male   NaN      2      0  21.6792        C   Third
# 49          0       3  female  18.0      1      0  17.8000        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15  \
# 45     man        True  NaN  Southampton    no   True          NaN
# 46     man        True  NaN   Queenstown    no  False          NaN
# 47   woman       False  NaN   Queenstown   yes   True          NaN
# 48     man        True  NaN    Cherbourg    no  False          NaN
# 49   woman       False  NaN  Southampton    no  False          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
#      Unnamed: 16
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# ..           ...
# 886          NaN
# 887          NaN
# 888          NaN
# 889          NaN
# 890          NaN
#
# [846 rows x 17 columns]

# %%
shape=df.shape
print(shape)
# Out:
# (891, 17)

# %%
df['age'].min()
# Out:
# 0.42

# %%
df['age'].max()
# Out:
# 80.0

# %%
df[45:87]
# Out:
#     survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 45         0       3    male    NaN      0      0   8.0500        S   Third
# 46         0       3    male    NaN      1      0  15.5000        Q   Third
# 47         1       3  female    NaN      0      0   7.7500        Q   Third
# 48         0       3    male    NaN      2      0  21.6792        C   Third
# 49         0       3  female  18.00      1      0  17.8000        S   Third
# 50         0       3    male   7.00      4      1  39.6875        S   Third
# 51         0       3    male  21.00      0      0   7.8000        S   Third
# 52         1       1  female  49.00      1      0  76.7292        C   First
# 53         1       2  female  29.00      1      0  26.0000        S  Second
# 54         0       1    male  65.00      0      1  61.9792        C   First
# 55         1       1    male    NaN      0      0  35.5000        S   First
# 56         1       2  female  21.00      0      0  10.5000        S  Second
# 57         0       3    male  28.50      0      0   7.2292        C   Third
# 58         1       2  female   5.00      1      2  27.7500        S  Second
# 59         0       3    male  11.00      5      2  46.9000        S   Third
# 60         0       3    male  22.00      0      0   7.2292        C   Third
# 61         1       1  female  38.00      0      0  80.0000      NaN   First
# 62         0       1    male  45.00      1      0  83.4750        S   First
# 63         0       3    male   4.00      3      2  27.9000        S   Third
# 64         0       1    male    NaN      0      0  27.7208        C   First
# 65         1       3    male    NaN      1      1  15.2458        C   Third
# 66         1       2  female  29.00      0      0  10.5000        S  Second
# 67         0       3    male  19.00      0      0   8.1583        S   Third
# 68         1       3  female  17.00      4      2   7.9250        S   Third
# 69         0       3    male  26.00      2      0   8.6625        S   Third
# 70         0       2    male  32.00      0      0  10.5000        S  Second
# 71         0       3  female  16.00      5      2  46.9000        S   Third
# 72         0       2    male  21.00      0      0  73.5000        S  Second
# 73         0       3    male  26.00      1      0  14.4542        C   Third
# 74         1       3    male  32.00      0      0  56.4958        S   Third
# 75         0       3    male  25.00      0      0   7.6500        S   Third
# 76         0       3    male    NaN      0      0   7.8958        S   Third
# 77         0       3    male    NaN      0      0   8.0500        S   Third
# 78         1       2    male   0.83      0      2  29.0000        S  Second
# 79         1       3  female  30.00      0      0  12.4750        S   Third
# 80         0       3    male  22.00      0      0   9.0000        S   Third
# 81         1       3    male  29.00      0      0   9.5000        S   Third
# 82         1       3  female    NaN      0      0   7.7875        Q   Third
# 83         0       1    male  28.00      0      0  47.1000        S   First
# 84         1       2  female  17.00      0      0  10.5000        S  Second
# 85         1       3  female  33.00      3      0  15.8500        S   Third
# 86         0       3    male  16.00      1      3  34.3750        S   Third
#
#       who  adult_male deck  embark_town alive  alone  Unnamed: 15  Unnamed: 16
# 45    man        True  NaN  Southampton    no   True          NaN          NaN
# 46    man        True  NaN   Queenstown    no  False          NaN          NaN
# 47  woman       False  NaN   Queenstown   yes   True          NaN          NaN
# 48    man        True  NaN    Cherbourg    no  False          NaN          NaN
# 49  woman       False  NaN  Southampton    no  False          NaN          NaN
# 50  child       False  NaN  Southampton    no  False          NaN          NaN
# 51    man        True  NaN  Southampton    no   True          NaN          NaN
# 52  woman       False    D    Cherbourg   yes  False          NaN          NaN
# 53  woman       False  NaN  Southampton   yes  False          NaN          NaN
# 54    man        True    B    Cherbourg    no  False          NaN          NaN
# 55    man        True    C  Southampton   yes   True          NaN          NaN
# 56  woman       False  NaN  Southampton   yes   True          NaN          NaN
# 57    man        True  NaN    Cherbourg    no   True          NaN          NaN
# 58  child       False  NaN  Southampton   yes  False          NaN          NaN
# 59  child       False  NaN  Southampton    no  False          NaN          NaN
# 60    man        True  NaN    Cherbourg    no   True          NaN          NaN
# 61  woman       False    B          NaN   yes   True          NaN          NaN
# 62    man        True    C  Southampton    no  False          NaN          NaN
# 63  child       False  NaN  Southampton    no  False          NaN          NaN
# 64    man        True  NaN    Cherbourg    no   True          NaN          NaN
# 65    man        True  NaN    Cherbourg   yes  False          NaN          NaN
# 66  woman       False    F  Southampton   yes   True          NaN          NaN
# 67    man        True  NaN  Southampton    no   True          NaN          NaN
# 68  woman       False  NaN  Southampton   yes  False          NaN          NaN
# 69    man        True  NaN  Southampton    no  False          NaN          NaN
# 70    man        True  NaN  Southampton    no   True          NaN          NaN
# 71  woman       False  NaN  Southampton    no  False          NaN          NaN
# 72    man        True  NaN  Southampton    no   True          NaN          NaN
# 73    man        True  NaN    Cherbourg    no  False          NaN          NaN
# 74    man        True  NaN  Southampton   yes   True          NaN          NaN
# 75    man        True    F  Southampton    no   True          NaN          NaN
# 76    man        True  NaN  Southampton    no   True          NaN          NaN
# 77    man        True  NaN  Southampton    no   True          NaN          NaN
# 78  child       False  NaN  Southampton   yes  False          NaN          NaN
# 79  woman       False  NaN  Southampton   yes   True          NaN          NaN
# 80    man        True  NaN  Southampton    no   True          NaN          NaN
# 81    man        True  NaN  Southampton   yes   True          NaN          NaN
# 82  woman       False  NaN   Queenstown   yes   True          NaN          NaN
# 83    man        True  NaN  Southampton    no   True          NaN          NaN
# 84  woman       False  NaN  Southampton   yes   True          NaN          NaN
# 85  woman       False  NaN  Southampton   yes  False          NaN          NaN
# 86    man        True  NaN  Southampton    no  False          NaN          NaN
